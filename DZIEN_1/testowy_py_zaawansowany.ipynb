# %%
a = "kilka słów więcej!"
print(a)
# Out:
# kilka słów więcej!

# %%
e = 5
d = 16
suma = e+d
suma + policz(e,d,13)
# Out:
# 294

# %%
def policz(a,b,n):
    return (a+b)*n

# %%
print(policz(3,5,67))
# Out:
# 536

# %% [markdown]
# To jest **notebook** zawierający <span style="color:red; font-size:16pt">komórki z kodem</span>!
